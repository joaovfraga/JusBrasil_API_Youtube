# %% [markdown]
# <a href="https://colab.research.google.com/github/joaovfraga/JusBrasil_API_Youtube/blob/main/JusBrasil_API_YouTube.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade google-api-python-client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.8/dist-packages (2.70.0)
# Collecting google-api-python-client
#   Downloading google_api_python_client-2.79.0-py2.py3-none-any.whl (11.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 48.1 MB/s eta 0:00:00
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.8/dist-packages (from google-api-python-client) (0.17.4)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in /usr/local/lib/python3.8/dist-packages (from google-api-python-client) (2.16.1)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /usr/local/lib/python3.8/dist-packages (from google-api-python-client) (0.1.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.8/dist-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.8/dist-packages (from google-api-python-client) (2.11.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.8/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.58.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.8/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.25.1)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /usr/local/lib/python3.8/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.19.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (1.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2022.12.7)
# Installing collected packages: google-api-python-client
#   Attempting uninstall: google-api-python-client
#     Found existing installation: google-api-python-client 2.70.0
#     Uninstalling google-api-python-client-2.70.0:
#       Successfully uninstalled google-api-python-client-2.70.0
# Successfully installed google-api-python-client-2.79.0

# %%
from googleapiclient.discovery import build

# %%
youTubeApiKey="AIzaSyDe4p3IqRgBlgHbmp5aphi6i8jBqYFLIlY"

# %%
youtube = build('youtube','v3', developerKey=youTubeApiKey)

# %%
playlistId = 'PLnZDSg6s-_Z80XNoKg0MFM3LYFOKa9SAy'
playlistName = '#MaisJuntosDoQueNunca'
nextPage_token = None

# %%
playlist_videos = []

while True:
  res = youtube.playlistItems().list(part='snippet', playlistId = playlistId, maxResults=50, pageToken=nextPage_token).execute()
  playlist_videos += res['items']
  
  nextPage_token = res.get('nestPageToken')

  if nextPage_token is None:
    break

# %%
print("Número total de vídeos na Playlist: ", len(playlist_videos))
# Out:
# Número total de vídeos na Playlist:  31

# %%
videos_ids = list(map(lambda x: x['snippet']['resourceId']['videoId'], playlist_videos))

# %%
videos_ids
# Out:
# ['pD0NHbLRhJ8',
#  'LFwFptxdqG8',
#  'o9YEiHdV9Mw',
#  'ED5vJ-J5mk8',
#  'qGCsEogoxlg',
#  'SBtY_Z8hIjk',
#  '9FFruBHQXWA',
#  'lcTlmMrfJEo',
#  '7kMf-vjd1-8',
#  '7ZYfJNw6_pA',
#  'ntBeuu3ZzAg',
#  '1guLO42qTkM',
#  'ALIaHuTa38M',
#  'JX5XlAKxaNU',
#  'iYNn8-Dw5yY',
#  'KBF7s-a2yjU',
#  'gwTpX3Fy6gU',
#  'UGmrVxXRFP0',
#  'zn6h1ZXO0Xo',
#  'mc04OloxVHs',
#  '2xmnFSEfSp0',
#  'tVF0V0ZIKJU',
#  'Vwl1VrF4NrY',
#  'vMLnkkYTQQE',
#  'ivso2tj7NMM',
#  'jDiT7uf8TQ4',
#  'c0TmSkrQyLI',
#  '-CwcL8S3juc',
#  '5QGGUDrnb9M',
#  'wL5P7hKHVLI',
#  'O-5nNTQU1mw']

# %%
stats = []

for video_id in videos_ids:
  res = youtube.videos().list(part='statistics', id=video_id).execute()
  stats += res['items']

# %%
stats
# Out:
# [{'kind': 'youtube#video',
#   'etag': '6s13JJEsTgJLT7Y0OpJnVJJOGzI',
#   'id': 'pD0NHbLRhJ8',
#   'statistics': {'viewCount': '202',
#    'likeCount': '11',
#    'favoriteCount': '0',
#    'commentCount': '1'}},
#  {'kind': 'youtube#video',
#   'etag': 'ISTkxOiV44NOj47q2wKrUFmHkRY',
#   'id': 'LFwFptxdqG8',
#   'statistics': {'viewCount': '609',
#    'likeCount': '31',
#    'favoriteCount': '0',
#    'commentCount': '1'}},
#  {'kind': 'youtube#video',
#   'etag': 'WUia52YZ2CExgYwd6W1HEQ1c_ak',
#   'id': 'o9YEiHdV9Mw',
#   'statistics': {'viewCount': '353',
#    'likeCount': '14',
#    'favoriteCount': '0',
#    'commentCount': '1'}},
#  {'kind': 'youtube#video',
#   'etag': 'gFrG7sBK_LSqhulZwxV6k26N9B4',
#   'id': 'ED5vJ-J5mk8',
#   'statistics': {'viewCount': '331',
#    'likeCount': '16',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': 'nK1XtvI05Zbq8oMXaXkQBtNlq24',
#   'id': 'qGCsEogoxlg',
#   'statistics': {'viewCount': '1479',
#    'likeCount': '29',
#    'favoriteCount': '0',
#    'commentCount': '3'}},
#  {'kind': 'youtube#video',
#   'etag': 'PQ3DYeXrezCl_a77RUqQ6D7Ul7Q',
#   'id': 'SBtY_Z8hIjk',
#   'statistics': {'viewCount': '238',
#    'likeCount': '11',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': 'luhy7sOqC1UpWO4ppdP66qO-TYs',
#   'id': '9FFruBHQXWA',
#   'statistics': {'viewCount': '168',
#    'likeCount': '14',
#    'favoriteCount': '0',
#    'commentCount': '1'}},
#  {'kind': 'youtube#video',
#   'etag': 'hYgrAJfyQ6Xk0dOX91Kg921n04U',
#   'id': 'lcTlmMrfJEo',
#   'statistics': {'viewCount': '248',
#    'likeCount': '6',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': 'jjpVzW8i1TZTp_DYGbZYFlYc_5Q',
#   'id': '7kMf-vjd1-8',
#   'statistics': {'viewCount': '734',
#    'likeCount': '23',
#    'favoriteCount': '0',
#    'commentCount': '1'}},
#  {'kind': 'youtube#video',
#   'etag': 'AXxjNQ8HNDnExqwJamx2ZDTfAgI',
#   'id': '7ZYfJNw6_pA',
#   'statistics': {'viewCount': '101',
#    'likeCount': '2',
#    'favoriteCount': '0',
#    'commentCount': '1'}},
#  {'kind': 'youtube#video',
#   'etag': 'gyjahfxEKF2dysx1m85B3lxDO_g',
#   'id': 'ntBeuu3ZzAg',
#   'statistics': {'viewCount': '1053',
#    'likeCount': '17',
#    'favoriteCount': '0',
#    'commentCount': '3'}},
#  {'kind': 'youtube#video',
#   'etag': '_A3Mz1QnQe44PtcxB8dK9cvGIlo',
#   'id': '1guLO42qTkM',
#   'statistics': {'viewCount': '857',
#    'likeCount': '42',
#    'favoriteCount': '0',
#    'commentCount': '6'}},
#  {'kind': 'youtube#video',
#   'etag': 'cubKJtuyw_z2PeS54GN8spQVTBs',
#   'id': 'ALIaHuTa38M',
#   'statistics': {'viewCount': '373',
#    'likeCount': '22',
#    'favoriteCount': '0',
#    'commentCount': '3'}},
#  {'kind': 'youtube#video',
#   'etag': 'JclDzEstGm0C3mQf9ZYX1zM0qdM',
#   'id': 'JX5XlAKxaNU',
#   'statistics': {'viewCount': '775',
#    'likeCount': '28',
#    'favoriteCount': '0',
#    'commentCount': '5'}},
#  {'kind': 'youtube#video',
#   'etag': '4LR2uCUGt3NRnmKME5WQNJUELIo',
#   'id': 'iYNn8-Dw5yY',
#   'statistics': {'viewCount': '566',
#    'likeCount': '23',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': 't3OgEYA4MgAm774941-Fbt5C_WQ',
#   'id': 'KBF7s-a2yjU',
#   'statistics': {'viewCount': '470',
#    'likeCount': '11',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': '02gGrGoaj09pXyRNb2oS-iXj7PE',
#   'id': 'gwTpX3Fy6gU',
#   'statistics': {'viewCount': '312',
#    'likeCount': '9',
#    'favoriteCount': '0',
#    'commentCount': '1'}},
#  {'kind': 'youtube#video',
#   'etag': 'rWVp3rKKhPJ6Evin7rz-fG81uWU',
#   'id': 'UGmrVxXRFP0',
#   'statistics': {'viewCount': '161',
#    'likeCount': '5',
#    'favoriteCount': '0',
#    'commentCount': '1'}},
#  {'kind': 'youtube#video',
#   'etag': 'DTMb9MiH0t6XcJSctOI5iBq0mVM',
#   'id': 'zn6h1ZXO0Xo',
#   'statistics': {'viewCount': '532',
#    'likeCount': '24',
#    'favoriteCount': '0',
#    'commentCount': '1'}},
#  {'kind': 'youtube#video',
#   'etag': 'WOarHpmevDxAPZiRM_Qf5rL06eg',
#   'id': 'mc04OloxVHs',
#   'statistics': {'viewCount': '210',
#    'likeCount': '8',
#    'favoriteCount': '0',
#    'commentCount': '1'}},
#  {'kind': 'youtube#video',
#   'etag': 'CXYWV1q7lnAwAjm78cpNuWqJD2E',
#   'id': '2xmnFSEfSp0',
#   'statistics': {'viewCount': '299',
#    'likeCount': '9',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': '0DypqyZx5M6hZ6v6-Z5Qv7ZgcmY',
#   'id': 'tVF0V0ZIKJU',
#   'statistics': {'viewCount': '433',
#    'likeCount': '23',
#    'favoriteCount': '0',
#    'commentCount': '3'}},
#  {'kind': 'youtube#video',
#   'etag': 'b6VtvbvvmXwcfONdyyvXX0-2De8',
#   'id': 'Vwl1VrF4NrY',
#   'statistics': {'viewCount': '498',
#    'likeCount': '18',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': 'sRoGao4qe3kDzv_iS8zwEJ0XU9w',
#   'id': 'vMLnkkYTQQE',
#   'statistics': {'viewCount': '122',
#    'likeCount': '5',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': 'sZZoxpqK_jIf2YXXbzzOZVdtwK4',
#   'id': 'ivso2tj7NMM',
#   'statistics': {'viewCount': '587',
#    'likeCount': '27',
#    'favoriteCount': '0',
#    'commentCount': '1'}},
#  {'kind': 'youtube#video',
#   'etag': 'VQ-EObMR7nugTqFRe8ULZC_WIKw',
#   'id': 'jDiT7uf8TQ4',
#   'statistics': {'viewCount': '95',
#    'likeCount': '7',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': 'txX_X2iVuZiSP232kmMsUB9Gf-I',
#   'id': 'c0TmSkrQyLI',
#   'statistics': {'viewCount': '92',
#    'likeCount': '3',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': 'w6xJIx67c0Xo9ksdb4Rpz7XNGj8',
#   'id': '-CwcL8S3juc',
#   'statistics': {'viewCount': '369',
#    'likeCount': '25',
#    'favoriteCount': '0',
#    'commentCount': '3'}},
#  {'kind': 'youtube#video',
#   'etag': 'HUAJiy1KJJjIC6blDr5VQCBBBms',
#   'id': '5QGGUDrnb9M',
#   'statistics': {'viewCount': '320',
#    'likeCount': '17',
#    'favoriteCount': '0',
#    'commentCount': '1'}},
#  {'kind': 'youtube#video',
#   'etag': 'RI25e_MBDPFr1TU3_nZ_Q7g41N8',
#   'id': 'wL5P7hKHVLI',
#   'statistics': {'viewCount': '293',
#    'likeCount': '12',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': 'OwYpYBlkEfWpGzgqnl9Zg5W7D7c',
#   'id': 'O-5nNTQU1mw',
#   'statistics': {'viewCount': '130',
#    'likeCount': '6',
#    'favoriteCount': '0',
#    'commentCount': '1'}}]

# %%
videos_title = list(map(lambda x: x['snippet']['title'], playlist_videos))
url_thumbnails = list(map(lambda x: x['snippet']['thumbnails']['high']['url'], playlist_videos))
published_date = list(map(lambda x: x['snippet']['publishedAt'], playlist_videos))
video_description = list(map(lambda x: x['snippet']['description'], playlist_videos))
videoid = list(map(lambda x: x['snippet']['resourceId']['videoId'], playlist_videos))

# %%
liked = list(map(lambda x: int(x['statistics']['likeCount']), stats))
views = list(map(lambda x: int(x['statistics']['viewCount']), stats))
comment = list(map(lambda x: int(x['statistics']['commentCount']), stats))

# %%
from datetime import datetime 

extraction_date = [str(datetime.now())]*len(videos_ids)

# %%
import pandas as pd

# %%
playlist_df = pd.DataFrame({'title':videos_title,
      'video_id':videoid,
      'video_description':video_description,
      'published_date':published_date,
      'extraction_date':extraction_date,
      'likes':liked,
      'views':views,
      'comment':comment,
      'thumbnail': url_thumbnails})
playlist_df.head(31)
# Out:
#                                                 title     video_id  \
# 0                      Seguimos #MaisJuntosDoQueNunca  pD0NHbLRhJ8
# 1   #LIVE1: Os impactos do COVID-19 no Mercado Jur...  LFwFptxdqG8
# 2   #LIVE2: Economia e finanças em tempos de COVID...  o9YEiHdV9Mw
# 3   #LIVE3 - As consequências econômicas do distan...  ED5vJ-J5mk8
# 4   Perguntas e Respostas - COVID 19: Impacto nas ...  qGCsEogoxlg
# 5   #LIVE4 - Aprendizados com a China- Com Rafael ...  SBtY_Z8hIjk
# 6   #LIVE5 - Fora fake news: como navegar por info...  9FFruBHQXWA
# 7   #LIVE6 - Panorama de como as startups estao li...  lcTlmMrfJEo
# 8   Correspondentes jurídicos: como lidar com a qu...  7kMf-vjd1-8
# 9   #LIVE7: Uma conversa sob a ótica de quem pegou...  7ZYfJNw6_pA
# 10  Jusbrasil Responde: renegociação de contratos ...  ntBeuu3ZzAg
# 11  #LIVE8: Como utilizar os meios eletrônicos com...  1guLO42qTkM
# 12  Trabalhar à distância: o que aprendemos sobre ...  ALIaHuTa38M
# 13  #LIVE9: O impacto do COVID-19 no poder Judiciário  JX5XlAKxaNU
# 14  #LIVE10: Como as mudanças regulatórias afetam ...  iYNn8-Dw5yY
# 15  Conversa com especialistas - Publicidade na ad...  KBF7s-a2yjU
# 16  #LIVE11: Reflexos Constitucionais do combate a...  gwTpX3Fy6gU
# 17  Impactos de uma pandemia no Direito do Consumidor  UGmrVxXRFP0
# 18          #LIVE12: Oportunidades no Direito Digital  zn6h1ZXO0Xo
# 19  #LIVE11: Reflexos Constitucionais do combate a...  mc04OloxVHs
# 20  #LIVE13: Gestão de Pessoas com Empatia e Criat...  2xmnFSEfSp0
# 21  #LIVE14: Estratégias usadas por escritórios pa...  tVF0V0ZIKJU
# 22                 #LIVE15: Desafios na Advocacia 4.0  Vwl1VrF4NrY
